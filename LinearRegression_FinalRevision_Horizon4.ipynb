# %% [markdown]
# ### Forza Horizon 4 User Prediction

# %%
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime as ddt

# %% [markdown]
# ## Horizon 4

# %%
df_forza4=pd.read_csv('forza_horizon4_price.csv',index_col=None)

# %%
df_forza4['DateTime']=pd.to_datetime(df_forza4['DateTime'])

# %%
df_forza4['Year']=df_forza4['DateTime'].dt.year
df_forza4['Month']=df_forza4['DateTime'].dt.month
df_forza4['Day']=df_forza4['DateTime'].dt.day

# %%
forza4_price=df_forza4[['DateTime','Players','Final Price','Discount','Year','Month','Day']].copy()

# %%
forza4_price.head()
# Out:
#     DateTime  Players  Final Price  Discount  Year  Month  Day
# 0 2021-03-09     3125        59.99         0  2021      3    9
# 1 2021-03-10    14609        59.99         0  2021      3   10
# 2 2021-03-11    20203        59.99         0  2021      3   11
# 3 2021-03-12    21235        59.99         0  2021      3   12
# 4 2021-03-13    23993        59.99         0  2021      3   13

# %%
forza4_price['DateTime']
# Out:
# 0     2021-03-09
# 1     2021-03-10
# 2     2021-03-11
# 3     2021-03-12
# 4     2021-03-13
#          ...
# 866   2023-07-23
# 867   2023-07-24
# 868   2023-07-25
# 869   2023-07-26
# 870   2023-07-27
# Name: DateTime, Length: 871, dtype: datetime64[ns]

# %%
forza4_price['Date']=forza4_price['DateTime'].map(ddt.datetime.toordinal)
forza4_price.head()
# Out:
#     DateTime  Players  Final Price  Discount  Year  Month  Day    Date
# 0 2021-03-09     3125        59.99         0  2021      3    9  737858
# 1 2021-03-10    14609        59.99         0  2021      3   10  737859
# 2 2021-03-11    20203        59.99         0  2021      3   11  737860
# 3 2021-03-12    21235        59.99         0  2021      3   12  737861
# 4 2021-03-13    23993        59.99         0  2021      3   13  737862

# %%
plt.figure(figsize=(15,4))
plt.plot(forza4_price['Date'],forza4_price['Players'],c='r')
plt.grid()
plt.show()

plt.figure(figsize=(15,4))
plt.plot(forza4_price['DateTime'],forza4_price['Players'],c='b')
plt.grid()
plt.show()

# %%
i=0
while(forza4_price.Date[i]!=738250):
    i=i+1
print(i)
# Out:
# 392

# %%
count=0
for i in range(len(forza4_price)):
    if((forza4_price.Year[i]==2021) or ((forza4_price.Year[i]==2022)):
        print(forza4_price.Date[i])
        count=count+1
print(count)
# Out:
# 737858
# 737859
# 737860
# 737861
# 737862
# 737863
# 737864
# 737865
# 737866
# 737867
# 737868
# 737869
# 737870
# 737871
# 737872
# 737873
# 737874
# 737875
# 737876
# 737877
# 737878
# 737879
# 737880
# 737881
# 737882
# 737883
# 737884
# 737885
# 737886
# 737887
# 737888
# 737889
# 737890
# 737891
# 737892
# 737893
# 737894
# 737895
# 737896
# 737897
# 737898
# 737899
# 737900
# 737901
# 737902
# 737903
# 737904
# 737905
# 737906
# 737907
# 737908
# 737909
# 737910
# 737911
# 737912
# 737913
# 737914
# 737915
# 737916
# 737917
# 737918
# 737919
# 737920
# 737921
# 737922
# 737923
# 737924
# 737925
# 737926
# 737927
# 737928
# 737929
# 737930
# 737931
# 737932
# 737933
# 737934
# 737935
# 737936
# 737937
# 737938
# 737939
# 737940
# 737941
# 737942
# 737943
# 737944
# 737945
# 737946
# 737947
# 737948
# 737949
# 737950
# 737951
# 737952
# 737953
# 737954
# 737955
# 737956
# 737957
# 737958
# 737959
# 737960
# 737961
# 737962
# 737963
# 737964
# 737965
# 737966
# 737967
# 737968
# 737969
# 737970
# 737971
# 737972
# 737973
# 737974
# 737975
# 737976
# 737977
# 737978
# 737979
# 737980
# 737981
# 737982
# 737983
# 737984
# 737985
# 737986
# 737987
# 737988
# 737989
# 737990
# 737991
# 737992
# 737993
# 737994
# 737995
# 737996
# 737997
# 737998
# 737999
# 738000
# 738001
# 738002
# 738003
# 738004
# 738005
# 738006
# 738007
# 738008
# 738009
# 738010
# 738011
# 738012
# 738013
# 738014
# 738015
# 738016
# 738017
# 738018
# 738019
# 738020
# 738021
# 738022
# 738023
# 738024
# 738025
# 738026
# 738027
# 738028
# 738029
# 738030
# 738031
# 738032
# 738033
# 738034
# 738035
# 738036
# 738037
# 738038
# 738039
# 738040
# 738041
# 738042
# 738043
# 738044
# 738045
# 738046
# 738047
# 738048
# 738049
# 738050
# 738051
# 738052
# 738053
# 738054
# 738055
# 738056
# 738057
# 738058
# 738059
# 738060
# 738061
# 738062
# 738063
# 738064
# 738065
# 738066
# 738067
# 738068
# 738069
# 738070
# 738071
# 738072
# 738073
# 738074
# 738075
# 738076
# 738077
# 738078
# 738079
# 738080
# 738081
# 738082
# 738083
# 738084
# 738085
# 738086
# 738087
# 738088
# 738089
# 738090
# 738091
# 738092
# 738093
# 738094
# 738095
# 738096
# 738097
# 738098
# 738099
# 738100
# 738101
# 738102
# 738103
# 738104
# 738105
# 738106
# 738107
# 738108
# 738109
# 738110
# 738111
# 738112
# 738113
# 738114
# 738115
# 738116
# 738117
# 738118
# 738119
# 738120
# 738121
# 738122
# 738123
# 738124
# 738125
# 738126
# 738127
# 738128
# 738129
# 738130
# 738131
# 738132
# 738133
# 738134
# 738135
# 738136
# 738137
# 738138
# 738139
# 738140
# 738141
# 738142
# 738143
# 738144
# 738145
# 738146
# 738147
# 738148
# 738149
# 738150
# 738151
# 738152
# 738153
# 738154
# 738155
# 738156
# 738157
# 738158
# 738159
# 738160
# 738161
# 738162
# 738163
# 738164
# 738165
# 738166
# 738167
# 738168
# 738169
# 738170
# 738171
# 738172
# 738173
# 738174
# 738175
# 738176
# 738177
# 738178
# 738179
# 738180
# 738181
# 738182
# 738183
# 738184
# 738185
# 738186
# 738187
# 738188
# 738189
# 738190
# 738191
# 738192
# 738193
# 738194
# 738195
# 738196
# 738197
# 738198
# 738199
# 738200
# 738201
# 738202
# 738203
# 738204
# 738205
# 738206
# 738207
# 738208
# 738209
# 738210
# 738211
# 738212
# 738213
# 738214
# 738215
# 738216
# 738217
# 738218
# 738219
# 738220
# 738221
# 738222
# 738223
# 738224
# 738225
# 738226
# 738227
# 738228
# 738229
# 738230
# 738231
# 738232
# 738233
# 738234
# 738235
# 738236
# 738237
# 738238
# 738239
# 738240
# 738241
# 738242
# 738243
# 738244
# 738245
# 738246
# 738247
# 738248
# 738249
# 738250
# 738251
# 738252
# 738253
# 738254
# 738255
# 738256
# 738257
# 738258
# 738259
# 738260
# 738261
# 738262
# 738263
# 738264
# 738265
# 738266
# 738267
# 738268
# 738269
# 738270
# 738271
# 738272
# 738273
# 738274
# 738275
# 738276
# 738277
# 738278
# 738279
# 738280
# 738281
# 738282
# 738283
# 738284
# 738285
# 738286
# 738287
# 738288
# 738289
# 738290
# 738291
# 738292
# 738293
# 738294
# 738295
# 738296
# 738297
# 738298
# 738299
# 738300
# 738301
# 738302
# 738303
# 738304
# 738305
# 738306
# 738307
# 738308
# 738309
# 738310
# 738311
# 738312
# 738313
# 738314
# 738315
# 738316
# 738317
# 738318
# 738319
# 738320
# 738321
# 738322
# 738323
# 738324
# 738325
# 738326
# 738327
# 738328
# 738329
# 738330
# 738331
# 738332
# 738333
# 738334
# 738335
# 738336
# 738337
# 738338
# 738339
# 738340
# 738341
# 738342
# 738343
# 738344
# 738345
# 738346
# 738347
# 738348
# 738349
# 738350
# 738351
# 738352
# 738353
# 738354
# 738355
# 738356
# 738357
# 738358
# 738359
# 738360
# 738361
# 738362
# 738363
# 738364
# 738365
# 738366
# 738367
# 738368
# 738369
# 738370
# 738371
# 738372
# 738373
# 738374
# 738375
# 738376
# 738377
# 738378
# 738379
# 738380
# 738381
# 738382
# 738383
# 738384
# 738385
# 738386
# 738387
# 738388
# 738389
# 738390
# 738391
# 738392
# 738393
# 738394
# 738395
# 738396
# 738397
# 738398
# 738399
# 738400
# 738401
# 738402
# 738403
# 738404
# 738405
# 738406
# 738407
# 738408
# 738409
# 738410
# 738411
# 738412
# 738413
# 738414
# 738415
# 738416
# 738417
# 738418
# 738419
# 738420
# 738421
# 738422
# 738423
# 738424
# 738425
# 738426
# 738427
# 738428
# 738429
# 738430
# 738431
# 738432
# 738433
# 738434
# 738435
# 738436
# 738437
# 738438
# 738439
# 738440
# 738441
# 738442
# 738443
# 738444
# 738445
# 738446
# 738447
# 738448
# 738449
# 738450
# 738451
# 738452
# 738453
# 738454
# 738455
# 738456
# 738457
# 738458
# 738459
# 738460
# 738461
# 738462
# 738463
# 738464
# 738465
# 738466
# 738467
# 738468
# 738469
# 738470
# 738471
# 738472
# 738473
# 738474
# 738475
# 738476
# 738477
# 738478
# 738479
# 738480
# 738481
# 738482
# 738483
# 738484
# 738485
# 738486
# 738487
# 738488
# 738489
# 738490
# 738491
# 738492
# 738493
# 738494
# 738495
# 738496
# 738497
# 738498
# 738499
# 738500
# 738501
# 738502
# 738503
# 738504
# 738505
# 738506
# 738507
# 738508
# 738509
# 738510
# 738511
# 738512
# 738513
# 738514
# 738515
# 738516
# 738517
# 738518
# 738519
# 738520
# 663

# %%
print(forza4_price['Date'][0:664])
# Out:
# 0      737858
# 1      737859
# 2      737860
# 3      737861
# 4      737862
#         ...
# 659    738517
# 660    738518
# 661    738519
# 662    738520
# 663    738521
# Name: Date, Length: 664, dtype: int64

# %% [markdown]
# ### 2021-2022

# %%
from sklearn.model_selection import train_test_split

# %%
X=forza4_price['Date'][0:391]
Y=forza4_price['Players'][0:391]

X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.8 , random_state=100)

# %%
X_train = X_train[:, np.newaxis]
X_test = X_test[:, np.newaxis]
# Out:
# /var/folders/ld/zxygdjc50qn3ct35m3lccwg80000gn/T/ipykernel_26785/1179647778.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_train = X_train[:, np.newaxis]
# /var/folders/ld/zxygdjc50qn3ct35m3lccwg80000gn/T/ipykernel_26785/1179647778.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_test = X_test[:, np.newaxis]

# %%
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

# Fit the model using lr.fit()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 13069256.544267809
# [-17.68656012]

# %%
print(lr.coef_*28)
print((lr.coef_)*28+lr.intercept_)
# Out:
# [-495.22368349]
# [13068761.32058432]

# %% [markdown]
# ### In the year 2021-2022, average decrease 500K per month 500000 (check data below)

# %%
forza4_price.head()
# Out:
#     DateTime  Players  Final Price  Discount  Year  Month  Day    Date
# 0 2021-03-09     3125        59.99         0  2021      3    9  737858
# 1 2021-03-10    14609        59.99         0  2021      3   10  737859
# 2 2021-03-11    20203        59.99         0  2021      3   11  737860
# 3 2021-03-12    21235        59.99         0  2021      3   12  737861
# 4 2021-03-13    23993        59.99         0  2021      3   13  737862

# %%
for i in range(392):
    if((forza4_price.Year[i]==2021) or (forza4_price.Year[i]==2022)):
        month=forza4_price.groupby(by='Month')['Players'].sum()
print(month)
# Out:
# Month
# 1      858158
# 2      631245
# 3      984317
# 4     1326295
# 5     1063595
# 6     1136205
# 7     1461301
# 8      658237
# 9     1099252
# 10     915728
# 11     793196
# 12     961122
# Name: Players, dtype: int64

# %%
np.mean(month.pct_change())
# Out:
# 0.07545846573227498

# %% [markdown]
# ### 2022-23

# %%
print(len(forza4_price))
# Out:
# 871

# %%
month2=forza4_price.groupby(["Year", "Month"])['Players'].sum() 
print(month2)
print(402404+632724+397251+450776+785979+408197+407330+393751)
# Out:
# Year  Month
# 2021  3        402404
#       4        632724
#       5        397251
#       6        450776
#       7        785979
#       8        408197
#       9        407330
#       10       393751
#       11       426320
#       12       592872
# 2022  1        494720
#       2        376256
#       3        274108
#       4        366345
#       5        315626
#       6        340294
#       7        360456
#       8        250040
#       9        691922
#       10       521977
#       11       366876
#       12       368250
# 2023  1        363438
#       2        254989
#       3        307805
#       4        327226
#       5        350718
#       6        345135
#       7        314866
# Name: Players, dtype: int64
# 3878412

# %%
print('**2021-2022**')
print(397251-632724)
print(632724-402404)
print(785979-450776)
print(785979-408197)
print('average:450k')

print('**2022-2023**')

print(592872-426320)
print(494720-592872)
print(376256-494720)
print(314866-345135)
print('average:100k')
# Out:
# **2021-2022**
# -235473
# 230320
# 335203
# 377782
# average:450k
# **2022-2023**
# 166552
# -98152
# -118464
# -30269
# average:100k

# %%
X2=forza4_price['Date'][393:]
Y2=forza4_price['Players'][393:]

X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, Y2, train_size=0.8 , random_state=100)

# %%
X_train2 = X_train2[:, np.newaxis]
X_test2 = X_test2[:, np.newaxis]
# Out:
# /var/folders/ld/zxygdjc50qn3ct35m3lccwg80000gn/T/ipykernel_26785/7030260.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_train2 = X_train2[:, np.newaxis]
# /var/folders/ld/zxygdjc50qn3ct35m3lccwg80000gn/T/ipykernel_26785/7030260.py:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X_test2 = X_test2[:, np.newaxis]

# %%
lr = LinearRegression()

# Fit the model using lr.fit()
lr.fit(X_train2, y_train2)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 2657406.1409390853
# [-3.58196389]

# %%
print((lr.coef_)*28)
print((lr.coef_)*28+lr.intercept_)
# Out:
# [-100.29498891]
# [2657305.84595018]

# %% [markdown]
# ### In the year 2022-2023, average decrease 100K per month 100000
